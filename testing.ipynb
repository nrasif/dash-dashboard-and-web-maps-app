# %%
import pandas as pd
import geopandas as gpd

data_well = gpd.read_file('./data/geojson/all_wells_ed.geojson')
data_well
# Out:
#       name       orient       status      purpose   type  \
# 0  Well-E1  Directional       Active   Production    Oil
# 1  Well-N1     Vertical       Active   Production    Gas
# 2  Well-W1  Directional       Active   Production    Oil
# 3  Well-E2  Directional  Abandonment  Exploration    Oil
# 4  Well-N2  Directional      Shut-in    Injection  Water
# 5  Well-C1     Vertical       Active   Production    Oil
# 6  Well-S1  Directional       Active   Production    Gas
# 7  Well-W2     Vertical      Shut-in    Injection  Water
# 8  Well-E3   Horizontal    Suspended   Monitoring    Oil
#
#                    geometry
# 0  POINT (96.33069 5.27458)
# 1  POINT (96.19868 5.44510)
# 2  POINT (96.11406 5.33654)
# 3  POINT (96.30160 5.32452)
# 4  POINT (96.10940 5.43308)
# 5  POINT (96.21456 5.36823)
# 6  POINT (96.17558 5.30896)
# 7  POINT (96.09407 5.38058)
# 8  POINT (96.44064 5.26732)

# %%
data_well['name'].unique().tolist()
# Out:
# ['Well-E1',
#  'Well-N1',
#  'Well-W1',
#  'Well-E2',
#  'Well-N2',
#  'Well-C1',
#  'Well-S1',
#  'Well-W2',
#  'Well-E3']

# %%
df = data_well[~data_well.isin(['Well-E2', 'Well-E3']).any(axis=1)]

# %%
gpd.GeoDataFrame
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
df
# Out:
#       name       orient   status     purpose   type                  geometry
# 0  Well-E1  Directional   Active  Production    Oil  POINT (96.33069 5.27458)
# 1  Well-N1     Vertical   Active  Production    Gas  POINT (96.19868 5.44510)
# 2  Well-W1  Directional   Active  Production    Oil  POINT (96.11406 5.33654)
# 4  Well-N2  Directional  Shut-in   Injection  Water  POINT (96.10940 5.43308)
# 5  Well-C1     Vertical   Active  Production    Oil  POINT (96.21456 5.36823)
# 6  Well-S1  Directional   Active  Production    Gas  POINT (96.17558 5.30896)
# 7  Well-W2     Vertical  Shut-in   Injection  Water  POINT (96.09407 5.38058)

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 7 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7 non-null      object
#  1   orient    7 non-null      object
#  2   status    7 non-null      object
#  3   purpose   7 non-null      object
#  4   type      7 non-null      object
#  5   geometry  7 non-null      geometry
# dtypes: geometry(1), object(5)
# memory usage: 392.0+ bytes

# %%
blocks = gpd.read_file('./data/geojson/all_blocks_ed.geojson')
blocks
# Out:
#            name       status operator  num_well   sq_km  reserve  \
# 0    East-Block  Exploration        A        20  145.97      100
# 1    West-Block   Production        B        50  171.38      420
# 2   South-Block   Production        A        10   48.74      150
# 3  Center-Block   Production        C        10   48.98      120
# 4   North-Block   Production        A        30   64.55      220
#
#                                             geometry
# 0  MULTIPOLYGON (((96.40011 5.20866, 96.32663 5.2...
# 1  MULTIPOLYGON (((96.15006 5.27447, 96.14025 5.2...
# 2  MULTIPOLYGON (((96.15021 5.32141, 96.26108 5.3...
# 3  MULTIPOLYGON (((96.15021 5.32141, 96.14887 5.4...
# 4  MULTIPOLYGON (((96.08469 5.41977, 96.08524 5.4...

# %%
output_file = './data/geopandas/all_wells_ed_modified.geojson'
df.to_file(output_file, driver='GeoJSON')

# %%
data = pd.read_csv('./data/csv/aceh_production_data_daily_ed.csv')
data
# Out:
#           DATEPRD WELL_BORE_CODE  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0      2008-02-12        Well-C1            0.0                    0.0
# 1      2008-02-13        Well-C1            0.0                    0.0
# 2      2008-02-14        Well-C1            0.0                    0.0
# 3      2008-02-15        Well-C1            0.0                    0.0
# 4      2008-02-16        Well-C1            0.0                    0.0
# ...           ...            ...            ...                    ...
# 15629  2016-10-05        Well-W2            NaN                    NaN
# 15630  2016-10-06        Well-W2            NaN                    NaN
# 15631  2016-10-07        Well-W2            NaN                    NaN
# 15632  2016-11-01        Well-W2            NaN                    NaN
# 15633  2016-12-01        Well-W2            NaN                    NaN
#
#        AVG_DP_TUBING  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# ...

# %%
filtered_list = [item for item in first_list if item not in second_list]
filtered_list
# Out:
# ['Well-E2', 'Well-E3']

# %%
import pandas as pd

data2 = pd.read_csv('./data/csv/aceh_log_data_ed.csv')
data2
# Out:
#        WELL_BORE_CODE     DEPTH_MD     X_LOC    Y_LOC       Z_LOC       CALI  \
# 0             Well-C1   439.415790  96.21456  5.36823 -414.377716  19.109173
# 1             Well-C1   439.567790  96.21456  5.36823 -414.529694  19.109400
# 2             Well-C1   439.719790  96.21456  5.36823 -414.681702  19.109400
# 3             Well-C1   439.871790  96.21456  5.36823 -414.833710  19.109400
# 4             Well-C1   440.023790  96.21456  5.36823 -414.985687  19.094189
# ...               ...          ...       ...      ...         ...        ...
# 125399        Well-W2  2361.275200  96.09407  5.38058         NaN   8.588360
# 125400        Well-W2  2361.427199  96.09407  5.38058         NaN   8.587591
# 125401        Well-W2  2361.579199  96.09407  5.38058         NaN   8.594840
# 125402        Well-W2  2361.731200  96.09407  5.38058         NaN   8.594312
# 125403        Well-W2  2361.883200  96.09407  5.38058         NaN   8.591199
#
# ...

# %%
data2['WELL_BORE_CODE'].unique()
# Out:
# array(['Well-C1', 'Well-E1', 'Well-E2', 'Well-E3', 'Well-N1', 'Well-N2',
#        'Well-S1', 'Well-W1', 'Well-W2'], dtype=object)

# %%
data.pivot_table(values=['AVG_DP_TUBING','ON_STREAM_HRS'],index=['DATEPRD', 'WELL_BORE_CODE'],aggfunc=sum)
# Out:
#                            AVG_DP_TUBING  ON_STREAM_HRS
# DATEPRD    WELL_BORE_CODE
# 2007-09-01 Well-N2                   0.0            0.0
#            Well-W2                   0.0            0.0
# 2007-09-02 Well-N2                   0.0            0.0
#            Well-W2                   0.0            0.0
# 2007-09-03 Well-N2                   0.0            0.0
# ...                                  ...            ...
# 2016-10-05 Well-W2                   0.0            0.0
# 2016-10-06 Well-W2                   0.0            0.0
# 2016-10-07 Well-W2                   0.0            0.0
# 2016-11-01 Well-W2                   0.0            0.0
# 2016-12-01 Well-W2                   0.0            0.0
#
# [15634 rows x 2 columns]
